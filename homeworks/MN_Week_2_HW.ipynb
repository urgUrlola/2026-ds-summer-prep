# %% [markdown]
# # Googling how to do something is NOT cheating.
# # Googling how to do figure something out is ENCOURAGED.

# %% [markdown]
# ## #1 Figure out how to print the current date and time.
# The solution should be in this format:  2021-08-05 11:56:30 (YYYY-MM-DD HH:MM:SS)
#
# Hint:  You're going to have to import a library

# %%
from datetime import datetime

print(f"Current date and time: {datetime.now()}")
# Out:
# Current date and time: 2026-08-02 01:26:02.547538

# %% [markdown]
# ## #2 Write a function that accepts the radius of a circle and returns the area of a circle.
# The function for the area of a circle is pi * radius squared.

# %%
import math

def area(radius):
    return math.pi * (radius ** 2)

radiusInput = 5
result = area(radiusInput)
print(f"Areas of circle with radius {radiusInput} is {result}")
# Out:
# Areas of circle with radius 5 is 78.53981633974483

# %% [markdown]
# ## #3 Write a function that takes a list of numbers and returns True of all number in the list are unique and returns False if the list contains duplicate numbers.
# * Hint, maybe think of using a set()
#
# Input:  input_list = [2,4,5,5,7,9]
#
# Expected Output:  False

# %%
def containsDuplicates(nums):
    return len(nums) == len(set(nums))

list1 = [2,4,5,7,9]
print(f"Input: {list1}")
print(f"Expected Output: {containsDuplicates(list1)}")

list2 = [2,4,5,5,7,9]
print(f"Input: {list2}")
print(f"Expected Output: {containsDuplicates(list2)}")
# Out:
# Input: [2, 4, 5, 7, 9]
# Expected Output: True
# Input: [2, 4, 5, 5, 7, 9]
# Expected Output: False

# %% [markdown]
# ## #4 Write a Python program to count the number of each character of a given text of a text file.
# * Use the text file called 'lil-wayne.txt' in the data folder.
# * Convert all the characters to uppercase first, then count them.
# * Use a dictionary in which the keys of the dictionary are the characters, and the values are the counts of that character.
#
# Expected Result:  `{'D': 74, 'W': 63, 'A': 211, 'Y': 44, 'N': 165, 'E': 274, ' ': 522, 'M': 77, 'I': 185, 'C': 60, 'H': 122, 'L': 126, 'R': 152, 'T': 180, 'J': 8, '.': 26, '(': 12, 'B': 59, 'O': 145, 'S': 152, 'P': 39, '2': 24, '7': 7, ',': 37, '1': 28, '9': 16, '8': 6, ')': 12, '[': 14, ']': 14, 'K': 13, 'F': 44, 'G': 53, 'X': 5, 'U': 66, 'V': 20, '3': 2, '4': 4, '5': 5, '6': 3, '0': 36, '\n': 6, '-': 6, ';': 1, '!': 1, '"': 8, "'": 3, '—': 1}`

# %%
f = open('/workspaces/2026-ds-summer-prep/Week-02/intermediate/data/lil-wayne.txt').read().upper()
charCount = {}

for char in f:
     charCount[char] = charCount.get(char, 0) + 1
     
print(f"Expected Result: {charCount}")
# Out:
# Expected Result: {'D': 74, 'W': 63, 'A': 211, 'Y': 44, 'N': 165, 'E': 274, ' ': 522, 'M': 77, 'I': 185, 'C': 60, 'H': 122, 'L': 126, 'R': 152, 'T': 180, 'J': 8, '.': 26, '(': 12, 'B': 59, 'O': 145, 'S': 152, 'P': 39, '2': 24, '7': 7, ',': 37, '1': 28, '9': 16, '8': 6, ')': 12, '[': 14, ']': 14, 'K': 13, 'F': 44, 'G': 53, 'X': 5, 'U': 66, 'V': 20, '3': 2, '4': 4, '5': 5, '6': 3, '0': 36, '\n': 6, '-': 6, ';': 1, '!': 1, '—': 1}

# %% [markdown]
# # 4.5 Figure out how to sort the dictionary to find which character appears the most.

# %%
sortedCharCount = dict(sorted(charCount.items(), key=lambda item: item[1], reverse=True))
print(f"Sorted Disctionary: {sortedCharCount}")
# Out:
# Sorted Disctionary: {' ': 522, 'E': 274, 'A': 211, 'I': 185, 'T': 180, 'N': 165, 'R': 152, 'S': 152, 'O': 145, 'L': 126, 'H': 122, 'M': 77, 'D': 74, 'U': 66, 'W': 63, 'C': 60, 'B': 59, 'G': 53, 'Y': 44, 'F': 44, 'P': 39, ',': 37, '0': 36, '1': 28, '.': 26, '2': 24, 'V': 20, '9': 16, '[': 14, ']': 14, 'K': 13, '(': 12, ')': 12, 'J': 8, '7': 7, '8': 6, '\n': 6, '-': 6, 'X': 5, '5': 5, '4': 4, '6': 3, '3': 2, ';': 1, '!': 1, '—': 1}

# %% [markdown]
# ## #5 Using the list below...
# * Remove the fourth number from the list.
# * Take that number you just removed and multiply the last number of the list by that number.
# * Append that number to the end of the list.
# * Print the list
#
# INPUT: [1, 1, 2, 3, 5, 8, 13, 21]
#
# EXPECTED OUTPUT:  [1, 1, 2, 5, 8, 13, 21, 63]

# %%
list1 = [1, 1, 2, 3, 5, 8, 13, 21]
print(f"INPUT: {list1}")
fourth = list1[3]
list1.pop(3)
list1.append(fourth * list1[-1])
print(f"EXPECTED OUTPUT: {list1}")
# Out:
# INPUT: [1, 1, 2, 3, 5, 8, 13, 21]
# EXPECTED OUTPUT: [1, 1, 2, 5, 8, 13, 21, 63]

# %% [markdown]
# ## #6 Using the list below, make a new list that contains only the numbers from the original list that are divisible by three.
#
# * Input:  original_list = [2, 3, 6, 8, 9, 15, 19, 21]
# * Expected new list:  [3, 6, 9, 15, 21]

# %%
original_list = [2, 3, 6, 8, 9, 15, 19, 21]
print(f"Input: original_list = {original_list}")

new_list = []
for n in original_list:
    if n % 3 == 0:
        new_list.append(n)

print(f"Expected new list: {new_list}")
# Out:
# Input: original_list = [2, 3, 6, 8, 9, 15, 19, 21]
# Expected new list: [3, 6, 9, 15, 21]

# %% [markdown]
# ## #7 Reverse the list below

# %%
original_list = [2, 3, 6, 8, 9, 15, 19, 21]
original_list.reverse()
print(f"Reversed List: {original_list}")
# Out:
# Reversed List: [21, 19, 15, 9, 8, 6, 3, 2]

# %% [markdown]
# ## #8 Using the list below, turn every item of the list into its square.
# * Input original_list = [1, 2, 3, 4, 5, 6, 7]
# * Expected new_list:  [1, 4, 9, 16, 25, 36, 49]

# %%
original_list = [1, 2, 3, 4, 5, 6, 7]
print(f"Input original_list = {original_list}")

original_list = [x**2 for x in original_list]
print(f"Expected new_list: {original_list}")
# Out:
# Input original_list = [1, 2, 3, 4, 5, 6, 7]
# Expected new_list: [1, 4, 9, 16, 25, 36, 49]

# %% [markdown]
# ## #9  Given a two Python list. Iterate both lists simultaneously such that list1 should display item in original order and list2 in reverse order.
# Given input:
# ```
# list1 = [10, 20, 30, 40]
# list2 = [100, 200, 300, 400]
# ```
#
# Expected Output:
# ```
# 10 400
# 20 300
# 30 200
# 40 100
# ```

# %%
list1 = [10, 20, 30, 40]
list2 = [100, 200, 300, 400]

for x, y in zip(list1, reversed(list2)):
    print(x, y)
# Out:
# 10 400
# 20 300
# 30 200
# 40 100

# %% [markdown]
# ## #10 Remove empty strings from the list of strings.
# Input:  `list_of_strings = ['I', 'love', '', '', 'data', '', 'science', '!']`
#
# Expected Output:  `['I', 'love', 'data', 'science', '!']`

# %%
list_of_strings = ['I', 'love', '', '', 'data', '', 'science', '!']
print(f"Input: {list_of_strings}")

list_of_strings = [x for x in list_of_strings if x]
print(f"Expected Output: {list_of_strings}")
# Out:
# Input: ['I', 'love', '', '', 'data', '', 'science', '!']
# Expected Output: ['I', 'love', 'data', 'science', '!']

# %% [markdown]
# ##  #11 Check if the value 999 exists in the dicitionary below.  If so, print true, if not print false.
#
# Input: sample_dict = {'a': 100, 'b': 999, 'c': 300}
#
# Expected Output:  True

# %%
sample_dict = {'a': 100, 'b': 999, 'c': 300}
print(f"Input: sample_dict = {sample_dict}")

expected_Output = 999 in sample_dict.values()
print(f"Expected Output: {expected_Output}")
# Out:
# Input: sample_dict = {'a': 100, 'b': 999, 'c': 300}
# Expected Output: True

# %% [markdown]
# # #12 Fix all the follow broken code snippets below
# (I got these examples from a great website, I will reference them later because they have the answers on them.)

# %%
greeting = "Hello, possible pirate! What's the password?"
password = 'admin'
message = greeting+password
if message in ("Arrr!"):
	print("Go away, pirate.")
else:
	print("Greetings, hater of pirates!")
# Out:
# Greetings, hater of pirates!

# %%
pages = 457
word_per_page = 250
number_of_pieces = 100

each_chunk = (pages * word_per_page)/number_of_pieces
print(each_chunk)
# Out:
# 1142.5

# %% [markdown]
# # Extra Credit

# %% [markdown]
# ## Using pandas, read the csv file in the data folder called `titianic.csv` and store it as a variable named `df`.

# %%
import pandas as pd

df = pd.read_csv('/workspaces/2026-ds-summer-prep/Week-02/intermediate/data/titanic.csv')
print(df)
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## I know we didn't cover this, but figure out how to find the mean age of the age column in your dataframe.

# %%
mean_age = df['age'].mean()
print(f"Mean age: {mean_age}")
# Out:
# Mean age: 29.69911764705882

# %% [markdown]
# ## What was the oldest and youngest ages on the titanic?

# %%
oldest_age = df['age'].max()
youngest_age = df['age'].min()
print(f"Oldest age: {oldest_age}")
print(f"Youngest age: {youngest_age}")
# Out:
# Oldest age: 80.0
# Youngest age: 0.42

# %% [markdown]
# ## How many people embarked from station 'S'?

# %%
embarked_S = (df['embarked'] == 'S').sum()
print(f"# of people embarked from station S: {embarked_S}")
# Out:
# # of people embarked from station S: 644
