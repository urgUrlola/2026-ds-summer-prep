# %% [markdown]
# # Googling how to do something is NOT cheating.
# # Googling how to do figure something out is ENCOURAGED.

# %% [markdown]
# ## #1 Figure out how to print the current date and time.
# The solution should be in this format:  2021-08-05 11:56:30 (YYYY-MM-DD HH:MM:SS)
#
# Hint:  You're going to have to import a library

# %%
from datetime import datetime

now = datetime.now()
print(now)
# Out:
# 2026-07-31 00:41:19.102776

# %% [markdown]
# ## #2 Write a function that accepts the radius of a circle and returns the area of a circle.
# The function for the area of a circle is pi * radius squared.

# %%
import math

def circleArea(radius):
    area = (math.pi * (radius ** 2))
    return area

circleArea(1)
# Out:
# 3.141592653589793

# %% [markdown]
# ## #3 Write a function that takes a list of numbers and returns True of all number in the list are unique and returns False if the list contains duplicate numbers.
# * Hint, maybe think of using a set()
#
# Input:  input_list = [2,4,5,5,7,9]
#
# Expected Output:  False

# %%
def uniqueList(list):
    return len(list) == len(set(list))

input_list = [2,4,5,5,7,9]
uniqueList(input_list)
# Out:
# False

# %% [markdown]
# ## #4 Write a Python program to count the number of each character of a given text of a text file.
# * Use the text file called 'lil-wayne.txt' in the data folder.
# * Convert all the characters to uppercase first, then count them.
# * Use a dictionary in which the keys of the dictionary are the characters, and the values are the counts of that character.
#
# Expected Result:  `{'D': 74, 'W': 63, 'A': 211, 'Y': 44, 'N': 165, 'E': 274, ' ': 522, 'M': 77, 'I': 185, 'C': 60, 'H': 122, 'L': 126, 'R': 152, 'T': 180, 'J': 8, '.': 26, '(': 12, 'B': 59, 'O': 145, 'S': 152, 'P': 39, '2': 24, '7': 7, ',': 37, '1': 28, '9': 16, '8': 6, ')': 12, '[': 14, ']': 14, 'K': 13, 'F': 44, 'G': 53, 'X': 5, 'U': 66, 'V': 20, '3': 2, '4': 4, '5': 5, '6': 3, '0': 36, '\n': 6, '-': 6, ';': 1, '!': 1, '"': 8, "'": 3, '—': 1}`

# %%
from pathlib import Path

def count_characters(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        text = f.read().upper()

    char_counts = {}
    for char in text:
        char_counts[char] = char_counts.get(char, 0) + 1

    return char_counts

filepath = Path("Week-02/intermediate/data/lil-wayne.txt")

result = count_characters(filepath)
print(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 14
#      11     return char_counts
#      13 filepath = Path("Week-02/intermediate/data/lil-wayne.txt")
# ---> 14 result = count_characters(filepath)
#      15 print(result)
#
# Cell In[7], line 4, in count_characters(filepath)
#       3 def count_characters(filepath):
# ----> 4     with open(filepath, 'r', encoding='utf-8') as f:
#       5         text = f.read().upper()
#       7     char_counts = {}
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# ...

# %% [markdown]
# # 4.5 Figure out how to sort the dictionary to find which character appears the most.

# %%
most_appear_char = max(result, key = result.get)
print(f"The most frequent character is {most_appear_char} appearing {result[most_appear_char]} times")

# %% [markdown]
# ## #5 Using the list below...
# * Remove the fourth number from the list.
# * Take that number you just removed and multiply the last number of the list by that number.
# * Append that number to the end of the list.
# * Print the list
#
# INPUT: [1, 1, 2, 3, 5, 8, 13, 21]
#
# EXPECTED OUTPUT:  [1, 1, 2, 5, 8, 13, 21, 63]

# %%
list1 = [1, 1, 2, 3, 5, 8, 13, 21]

fourth_indx = list1.pop(3)
new_indx = fourth_indx * list1[-1]
list1.append(new_indx)
print(list1)
# Out:
# [1, 1, 2, 5, 8, 13, 21, 63]

# %% [markdown]
# ## #6 Using the list below, make a new list that contains only the numbers from the original list that are divisible by three.
#
# * Input:  original_list = [2, 3, 6, 8, 9, 15, 19, 21]
# * Expected new list:  [3, 6, 9, 15, 21]

# %%
original_list = [2, 3, 6, 8, 9, 15, 19, 21]
new_list = []

for item in original_list:
    if item % 3 == 0:
        new_list.append(item)

print(new_list)
# Out:
# [3, 6, 9, 15, 21]

# %% [markdown]
# ## #7 Reverse the list below

# %%
original_list = [2, 3, 6, 8, 9, 15, 19, 21]

original_list.reverse()
print(original_list)
# Out:
# [21, 19, 15, 9, 8, 6, 3, 2]

# %% [markdown]
# ## #8 Using the list below, turn every item of the list into its square.
# * Input original_list = [1, 2, 3, 4, 5, 6, 7]
# * Expected new_list:  [1, 4, 9, 16, 25, 36, 49]

# %%
import math

original_list = [1, 2, 3, 4, 5, 6, 7]
new_list = []

for items in original_list:
    new_list.append(items**2)

print(new_list)
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %% [markdown]
# ## #9  Given a two Python list. Iterate both lists simultaneously such that list1 should display item in original order and list2 in reverse order.
# Given input:
# ```
# list1 = [10, 20, 30, 40]
# list2 = [100, 200, 300, 400]
# ```
#
# Expected Output:
# ```
# 10 400
# 20 300
# 30 200
# 40 100
# ```

# %%
list1 = [10, 20, 30, 40]
list2 = [100, 200, 300, 400]

list3 = list2[::-1]

for item1, item2 in zip(list1, list3):
    print (f"{item1} {item2}")
# Out:
# 10 400
# 20 300
# 30 200
# 40 100

# %% [markdown]
# ## #10 Remove empty strings from the list of strings.
# Input:  `list_of_strings = ['I', 'love', '', '', 'data', '', 'science', '!']`
#
# Expected Output:  `['I', 'love', 'data', 'science', '!']`

# %%
list_of_strings = ['I', 'love', '', '', 'data', '', 'science', '!']

removed_strings = list(filter(None, list_of_strings))
print(removed_strings)
# Out:
# ['I', 'love', 'data', 'science', '!']

# %% [markdown]
# ##  #11 Check if the value 999 exists in the dicitionary below.  If so, print true, if not print false.
#
# Input: sample_dict = {'a': 100, 'b': 999, 'c': 300}
#
# Expected Output:  True

# %%
sample_dict = {'a': 100, 'b': 999, 'c': 300}

if 999 in sample_dict.values():
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# # #12 Fix all the follow broken code snippets below
# (I got these examples from a great website, I will reference them later because they have the answers on them.)

# %%
greeting = "Hello, possible pirate! What's the password?"
password = 'admin'
message = greeting+password
if ("Arrr!") in message:
	print("Go away, pirate.")
else:
	print("Greetings, hater of pirates!")
# Out:
# Greetings, hater of pirates!

# %%
pages = 457
words_per_page = 250
number_of_pieces = 100

each_chunk = (pages * words_per_page)/number_of_pieces
print (each_chunk)
# Out:
# 1142.5

# %% [markdown]
# # Extra Credit

# %% [markdown]
# ## Using pandas, read the csv file in the data folder called `titianic.csv` and store it as a variable named `df`.

# %%
import pandas as pd
from pathlib import Path

candidate_paths = [
    Path("Week-02/intermediate/data/titanic.csv"),
    Path("../Week-02/intermediate/data/titanic.csv")
]

csv_path = next((p for p in candidate_paths if p.exists()), candidate_paths[0])
df = pd.read_csv(csv_path)

# %% [markdown]
# ## I know we didn't cover this, but figure out how to find the mean age of the age column in your dataframe.

# %%
df['Age'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df['Age'].mean()
#
# ...

# %% [markdown]
# ## What was the oldest and youngest ages on the titanic?

# %%
df['Age'].max()
df['Age'].min()

# %% [markdown]
# ## How many people embarked from station 'S'?
