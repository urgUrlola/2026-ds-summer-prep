# %% [markdown]
# # Googling how to do something is NOT cheating.
# # Googling how to do figure something out is ENCOURAGED.

# %% [markdown]
# ## #1 Figure out how to print the current date and time.
# The solution should be in this format:  2021-08-05 11:56:30 (YYYY-MM-DD HH:MM:SS)
#
# Hint:  You're going to have to import a library

# %%
import datetime

print(datetime.datetime.now())
# Out:
# 2026-07-30 19:54:05.254644

# %% [markdown]
# ## #2 Write a function that accepts the radius of a circle and returns the area of a circle.
# The function for the area of a circle is pi * radius squared.

# %%
import math

def area_of_circle(r): # r is radius
    return math.pi*r*r

for i in range(0,10):
    print(i, area_of_circle(i))
# Out:
# 0 0.0
# 1 3.141592653589793
# 2 12.566370614359172
# 3 28.274333882308138
# 4 50.26548245743669
# 5 78.53981633974483
# 6 113.09733552923255
# 7 153.93804002589985
# 8 201.06192982974676
# 9 254.46900494077323

# %% [markdown]
# ## #3 Write a function that takes a list of numbers and returns True if all numbers in the list are unique and returns False if the list contains duplicate numbers.
# * Hint, maybe think of using a set()
#
# Input:  input_list = [2,4,5,5,7,9]
#
# Expected Output:  False

# %%
def contains_dups(lst):
    return len(set(lst)) == len(lst)

print(contains_dups([2,4,5,5,7,9]))
print(contains_dups([2,4,5,7,9]))
# Out:
# False
# True

# %% [markdown]
# ## #4 Write a Python program to count the number of each character of a given text of a text file.
# * Use the text file called 'lil-wayne.txt' in the data folder.
# * Convert all the characters to uppercase first, then count them.
# * Use a dictionary in which the keys of the dictionary are the characters, and the values are the counts of that character.
#
# Expected Result:  `{'D': 74, 'W': 63, 'A': 211, 'Y': 44, 'N': 165, 'E': 274, ' ': 522, 'M': 77, 'I': 185, 'C': 60, 'H': 122, 'L': 126, 'R': 152, 'T': 180, 'J': 8, '.': 26, '(': 12, 'B': 59, 'O': 145, 'S': 152, 'P': 39, '2': 24, '7': 7, ',': 37, '1': 28, '9': 16, '8': 6, ')': 12, '[': 14, ']': 14, 'K': 13, 'F': 44, 'G': 53, 'X': 5, 'U': 66, 'V': 20, '3': 2, '4': 4, '5': 5, '6': 3, '0': 36, '\n': 6, '-': 6, ';': 1, '!': 1, '"': 8, "'": 3, '—': 1}`

# %%
file_path = '../Week-02/intermediate/data/lil-wayne.txt'
fh = open(file_path, 'r')

char_counts = dict()

for line in fh:
    for char in line:
        upper_char = char.upper()
        if upper_char in char_counts:
            char_counts[upper_char] += 1
        else:
            char_counts[upper_char] = 1

print(char_counts)
# Out:
# {'D': 74, 'W': 63, 'A': 211, 'Y': 44, 'N': 165, 'E': 274, ' ': 522, 'M': 77, 'I': 185, 'C': 60, 'H': 122, 'L': 126, 'R': 152, 'T': 180, 'J': 8, '.': 26, '(': 12, 'B': 59, 'O': 145, 'S': 152, 'P': 39, '2': 24, '7': 7, ',': 37, '1': 28, '9': 16, '8': 6, ')': 12, '[': 14, ']': 14, 'K': 13, 'F': 44, 'G': 53, 'X': 5, 'U': 66, 'V': 20, '3': 2, '4': 4, '5': 5, '6': 3, '0': 36, '\n': 6, '-': 6, ';': 1, '!': 1, 'Â': 1, '€': 1, '”': 1}

# %% [markdown]
# # 4.5 Figure out how to sort the dictionary to find which character appears the most.

# %%
from collections import OrderedDict
sorted_char_counts = OrderedDict(sorted(char_counts.items(), key=lambda item: item[1], reverse=True)) # I put it in reverse to see the character that appears most first
print(sorted_char_counts)
# Out:
# OrderedDict({' ': 522, 'E': 274, 'A': 211, 'I': 185, 'T': 180, 'N': 165, 'R': 152, 'S': 152, 'O': 145, 'L': 126, 'H': 122, 'M': 77, 'D': 74, 'U': 66, 'W': 63, 'C': 60, 'B': 59, 'G': 53, 'Y': 44, 'F': 44, 'P': 39, ',': 37, '0': 36, '1': 28, '.': 26, '2': 24, 'V': 20, '9': 16, '[': 14, ']': 14, 'K': 13, '(': 12, ')': 12, 'J': 8, '7': 7, '8': 6, '\n': 6, '-': 6, 'X': 5, '5': 5, '4': 4, '6': 3, '3': 2, ';': 1, '!': 1, 'Â': 1, '€': 1, '”': 1})

# %% [markdown]
# ## #5 Using the list below...
# * Remove the fourth number from the list.
# * Take that number you just removed and multiply the last number of the list by that number.
# * Append that number to the end of the list.
# * Print the list
#
# INPUT: [1, 1, 2, 3, 5, 8, 13, 21]
#
# EXPECTED OUTPUT:  [1, 1, 2, 5, 8, 13, 21, 63]

# %%
list1 = [1, 1, 2, 3, 5, 8, 13, 21]

removed = list1.pop(3)
list1.append(list1[-1]*removed)

print(list1)
# Out:
# [1, 1, 2, 5, 8, 13, 21, 63]

# %% [markdown]
# ## #6 Using the list below, make a new list that contains only the numbers from the original list that are divisible by three.
#
# * Input:  original_list = [2, 3, 6, 8, 9, 15, 19, 21]
# * Expected new list:  [3, 6, 9, 15, 21]

# %%
original_list = [2, 3, 6, 8, 9, 15, 19, 21]

new_list = [num for num in original_list if (num % 3 == 0)]

print("Original: ", original_list)
print("New: ", new_list)
# Out:
# Original:  [2, 3, 6, 8, 9, 15, 19, 21]
# New:  [3, 6, 9, 15, 21]

# %% [markdown]
# ## #7 Reverse the list below

# %%
original_list = [2, 3, 6, 8, 9, 15, 19, 21]

new_list = list(original_list) # copy constructor
new_list.reverse()

print("Original: ", original_list)
print("New: ", new_list)
# Out:
# Original:  [2, 3, 6, 8, 9, 15, 19, 21]
# New:  [21, 19, 15, 9, 8, 6, 3, 2]

# %% [markdown]
# ## #8 Using the list below, turn every item of the list into its square.
# * Input original_list = [1, 2, 3, 4, 5, 6, 7]
# * Expected new_list:  [1, 4, 9, 16, 25, 36, 49]

# %%
original_list = [1, 2, 3, 4, 5, 6, 7]

def square(num):
    return num*num

new_list = list(map(square, original_list))

print("Original: ", original_list)
print("New: ", new_list)
# Out:
# Original:  [1, 2, 3, 4, 5, 6, 7]
# New:  [1, 4, 9, 16, 25, 36, 49]

# %% [markdown]
# ## #9  Given a two Python list. Iterate both lists simultaneously such that list1 should display item in original order and list2 in reverse order.
# Given input:
# ```
# list1 = [10, 20, 30, 40]
# list2 = [100, 200, 300, 400]
# ```
#
# Expected Output:
# ```
# 10 400
# 20 300
# 30 200
# 40 100
# ```

# %%
list1 = [10, 20, 30, 40]
list2 = [100, 200, 300, 400]

for i, num in enumerate(list1):
    print(list1[i], list2[-(i+1)]) # or (-i-1)
# Out:
# 10 400
# 20 300
# 30 200
# 40 100

# %% [markdown]
# ## #10 Remove empty strings from the list of strings.
# Input:  `list_of_strings = ['I', 'love', '', '', 'data', '', 'science', '!']`
#
# Expected Output:  `['I', 'love', 'data', 'science', '!']`

# %%
list_of_strings = ['I', 'love', '', '', 'data', '', 'science', '!']

new_list_of_strings = [x for x in list_of_strings if x]

print(new_list_of_strings)
# Out:
# ['I', 'love', 'data', 'science', '!']

# %% [markdown]
# ##  #11 Check if the value 999 exists in the dicitionary below.  If so, print true, if not print false.
#
# Input: sample_dict = {'a': 100, 'b': 999, 'c': 300}
#
# Expected Output:  True

# %%
sample_dict = {'a': 100, 'b': 999, 'c': 300}

print(999 in sample_dict.values())
# Out:
# True

# %% [markdown]
# # #12 Fix all the follow broken code snippets below
# (I got these examples from a great website, I will reference them later because they have the answers on them.)

# %%
greeting = "Hello, possible pirate! What's the password?"
password = 'admin'
message = greeting+password
if "Arrr!" in message:
	print("Go away, pirate.")
else:
	print("Greetings, hater of pirates!")
# Out:
# Greetings, hater of pirates!

# %%
pages = 457
word_per_page = 250
number_of_pieces = 100

each_chunk = (457 * 250)/10 # could also be //

print(each_chunk)
# Out:
# 11425.0

# %% [markdown]
# # Extra Credit

# %% [markdown]
# ## Using pandas, read the csv file in the data folder called `titianic.csv` and store it as a variable named `df`.

# %%
# What is my reward for this?

import pandas as pd

file_path = '../Week-02/intermediate/data/titanic.csv'

df = pd.read_csv(file_path)
print(df)
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## I know we didn't cover this, but figure out how to find the mean age of the age column in your dataframe.

# %%
df["age"].mean()
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# ## What was the oldest and youngest ages on the titanic?

# %%
print("Oldest:", df["age"].max())
print("Youngest:", df["age"].min())
# Out:
# Oldest: 80.0
# Youngest: 0.42

# %% [markdown]
# ## How many people embarked from station 'S'?

# %%
print((df['embarked'] == 'S').sum()) # we turn this into a true false table
# Out:
# 644
