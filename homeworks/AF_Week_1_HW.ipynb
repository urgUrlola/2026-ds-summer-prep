# %% [markdown]
# ## ❌ DO NOT EDIT - MAKE A COPY
# # Q1: Alphabet Slices
# * Store the first ten letters of the alphabet in a list.
# * Use a slice to print out the first three letters of the alphabet.
# * Use a slice to print out any three letters from the middle of your list.

# %%
# Solve Alphabet slices here. 
## Extra Credit:  Do this without 'hard coding' the alpahbet.

lst = []
for i in range(65, 75): # 'A' is 65 in ASCII
    lst.append(chr(i))

print(len(lst)) # sanity check

print(lst)

# print out first 3 letters
print(lst[0:3])

# print any three letters from middle of list
print(lst[3:6])
# Out:
# 10
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']
# ['A', 'B', 'C']
# ['D', 'E', 'F']

# %% [markdown]
# # Q2:  Covert all the rapper names to title case and save them into a new different list.
# Example: **lil wayne** becomes **Lil Wayne**

# %%
# Solve rapper names here
rappers = ['lil wayne', 'nicki minaj', 'drake']

#
# lil wayne
# _
# Lil
#    _
#     w
#
#

new_rappers = []

for rapper in rappers:
    # we can start with the first letter of each rapper
    # if it's lowercase, make it uppercase
    # if rapper[0].islower():
    #     rapper = rapper[0].upper() + rapper[1:]

    # for index, char in enumerate(rapper):
    #     if char == ' ' and (index < len(rapper) and rapper[index+1].islower()):
    #         rapper = rapper[0:index] + char + rapper[index+1].upper() + rapper[index+2:]

    new_rappers.append(rapper.title())

print("old: ", rappers) 
print("new: ", new_rappers)
# Out:
# old:  ['lil wayne', 'nicki minaj', 'drake']
# new:  ['Lil Wayne', 'Nicki Minaj', 'Drake']

# %% [markdown]
# # Q3: Write a function that takes a number and returns:
# * True if the input number is even.
# * False if the input number is odd.

# %%
# Solve problem here

def even_odd(lst):
   return lst & 1 == 0 # if you are normal you could do (lst % 2 == 0), I used bitwise
   # return something
# Out:
# True

# %% [markdown]
# # Q4: Find the sum and the average of this list of numbers.
#
# Try doing this using a loop.  Then try doing this without using a loop.

# %%
# Solve problem here:

my_list = [1, 5, 10, 55, 88, 44, 42, 50, 20, 38]

# loop method:

list_sum1, list_sum2, list_avg1, list_avg2 = 0, 0, 0, 0
for num in my_list:
    list_sum1 += num
list_avg1 = list_sum1/len(my_list)
print(list_sum1)

list_sum2 = sum(my_list)
list_avg2 = list_sum2/len(my_list)

# Keep this as your last line in this cell.
print("Method 1: ", list_sum1, list_avg1)
print("Method 2: ", list_sum2, list_avg2)
# Out:
# 353
# Method 1:  353 35.3
# Method 2:  353 35.3

# %% [markdown]
# # Q5:
# ## Write a function that takes a list and returns a new list that has all the duplicates removed.
#
# Example input and expected output:
# - input = `["Michele", "Robin", "Sara", "Michele"]`
# - expected output = `['Michele', 'Robin', 'Sara']`

# %%
# Solve problem here:

names = ["Michele", "Robin", "Sara", "Michele"]

#print(list(dict.fromkeys(names))) # this works because order is maintained in a dictionary in entry order for the keys

def rm_dups(lst):
    return list(dict.fromkeys(lst))

print(rm_dups(names))
# Out:
# ['Michele', 'Robin', 'Sara']

# %% [markdown]
# # Q6: Write a function that takes a list of numbers
# (for example, `a = [5, 10, 15, 20, 25]`) and returns a new list of only the first and last elements of the given list.
#
# Example input and expected output:
# - input = `[5, 10, 15, 20, 25]`
# - expected output = `[5, 25]`

# %%
# Solve problem here:
input_list = [5, 10, 99, 20, 25]

def first_last(lst):
    return [input_list[0], input_list[-1]]

print(first_last(input_list))
# Out:
# [5, 25]

# %% [markdown]
# # Q7:
# ## Implement a function that takes as input three variables, and returns the largest of the three.
# ### Try doing this without using the `max()` function!
#
# _**Note:** all three input numbers will always be different, no need to account for a tie._
#
# Example input and expected output:
# - input: `your_function(1, 5, 10)`
# - expected output:  `10`

# %%
# Solve Problem here:

def my_max(a, b, c):
    # Fill in your code below and return max value of a, b, c
        
    mx = a
    if b > mx:
        mx = b
    if c > mx:
        mx = c
    return mx

print(my_max(1,5,10))
print(my_max(1,20,5))
print(my_max(7,6,5))
# Out:
# 10
# 20
# 7

# %%
# Test to see if your function works properly.
my_max(1, 5, 10)

# %% [markdown]
# # Q8: Write a function that takes a number as input and returns the following:
# * If the input is divisible by three, return `'fizz'`
# * If the input is divisible by five, return `'buzz'`
# * If the input is divisible by three and by five, return `'fizzbuzz'`
# * If the input is not divisible by three or five, return `None`.

# %%
# Solve Problem fizzbuzz here:

def fizzbuzz(num):
    str = ''
    if num % 3 == 0:
        str = 'fizz'
    if num % 5 == 0:
        str += 'buzz'
    return str if str else None

for i in range(0, 20):
    print(i, fizzbuzz(i))
# Out:
# 0 fizzbuzz
# 1 None
# 2 None
# 3 fizz
# 4 None
# 5 buzz
# 6 fizz
# 7 None
# 8 None
# 9 fizz
# 10 buzz
# 11 None
# 12 fizz
# 13 None
# 14 None
# 15 fizzbuzz
# 16 None
# 17 None
# 18 fizz
# 19 None
